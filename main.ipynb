# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd "/content/drive/My Drive/MLILAB/study/Show_Attend_and_Tell"
# !ls

# %%
# !python main.py --batch_size 256 --epochs 50 --prev_model '50.pt'
